# %%
from requests import get, post
from web3 import Web3, HTTPProvider
from icecream import ic
import numpy as np
import pandas as pd
import sys
from dotenv import load_dotenv
import os
import json
import matplotlib.pyplot as plt
from datetime import datetime
import time

# %%
# Load environment variables
load_dotenv()

# Get Etherscan API key from environment variables
ETHERSCAN_API_KEY = os.getenv("ETHERSCAN_KEY")
ALCHEMY_KEY = os.getenv("ALCHEMY_KEY_2")
INFURA_KEY = os.getenv("INFURA_KEY")

URL = f"https://eth-mainnet.g.alchemy.com/v2/{ALCHEMY_KEY}"

# %%
ABI = [{"inputs":[],"name":"getReservesList","outputs":[{"internalType":"address[]","name":"arg_0","type":"address[]"}],"stateMutability":"view","type":"function"},
       {"inputs":[{"internalType":"address","name":"asset","type":"address"}],"name":"getReserveData","outputs":[{"components":[{"components":[{"internalType":"uint256","name":"data","type":"uint256"}],"internalType":"struct DataTypes.ReserveConfigurationMap","name":"configuration","type":"tuple"},{"internalType":"uint128","name":"liquidityIndex","type":"uint128"},{"internalType":"uint128","name":"currentLiquidityRate","type":"uint128"},{"internalType":"uint128","name":"variableBorrowIndex","type":"uint128"},{"internalType":"uint128","name":"currentVariableBorrowRate","type":"uint128"},{"internalType":"uint128","name":"currentStableBorrowRate","type":"uint128"},{"internalType":"uint40","name":"lastUpdateTimestamp","type":"uint40"},{"internalType":"uint16","name":"id","type":"uint16"},{"internalType":"address","name":"aTokenAddress","type":"address"},{"internalType":"address","name":"stableDebtTokenAddress","type":"address"},{"internalType":"address","name":"variableDebtTokenAddress","type":"address"},{"internalType":"address","name":"interestRateStrategyAddress","type":"address"},{"internalType":"uint128","name":"accruedToTreasury","type":"uint128"},{"internalType":"uint128","name":"unbacked","type":"uint128"},{"internalType":"uint128","name":"isolationModeTotalDebt","type":"uint128"}],"internalType":"struct DataTypes.ReserveDataLegacy","name":"arg_0","type":"tuple"}],"stateMutability":"view","type":"function"},
       ]
POOL_ADDRESS = "0x87870Bca3F3fD6335C3F4ce8392D69350B4fA4E2"
W3 = Web3(HTTPProvider(URL))

ABI_RESERVE = [{"inputs":[],"name":"getAllReservesTokens","outputs":[{"components":[{"internalType":"string","name":"symbol","type":"string"},{"internalType":"address","name":"tokenAddress","type":"address"}],"internalType":"struct IPoolDataProvider.TokenData[]","name":"","type":"tuple[]"}],"stateMutability":"view","type":"function"}]
DATA_PROVIDER = "0x7B4EB56E7CD4b454BA8ff71E4518426369a138a3"

# %%
def get_reserve_list(block_number=None):
    
    try:
        # Create contract instance
        contract = W3.eth.contract(address=Web3.to_checksum_address(DATA_PROVIDER), abi=ABI_RESERVE)
        
        # Get the contract function
        contract_function = getattr(contract.functions, "getAllReservesTokens")
        
        # Call the function with arguments and block identifier if provided
        if block_number is not None:
            data = contract_function().call(block_identifier=int(block_number))
        else:
            data = contract_function().call()
        
        return data
    
    except Exception as e:
        return f'Error querying smart contract: {e}'
    
    
def get_asset_data(asset, block_number=None):
    
    try:
        # Create contract instance
        contract = W3.eth.contract(address=Web3.to_checksum_address(POOL_ADDRESS), abi=ABI)
        
        # Get the contract function
        contract_function = getattr(contract.functions, "getReserveData")
        
        # Call the function with arguments and block identifier if provided
        if block_number is not None:
            data = contract_function(asset).call(block_identifier=int(block_number))
        else:
            data = contract_function(asset).call()
        
        return data
    
    except Exception as e:
        return f'Error querying smart contract: {e}'
    
# def get_data_from_pool(function_name, *args, block_number=None):
    
#     try:
#         # Create contract instance
#         contract = W3.eth.contract(address=Web3.to_checksum_address(POOL_ADDRESS), abi=ABI)
        
#         # Get the contract function
#         contract_function = getattr(contract.functions, function_name)
        
#         # Call the function with arguments and block identifier if provided
#         if block_number is not None:
#             data = contract_function(*args).call(block_identifier=int(block_number))
#         else:
#             data = contract_function(*args).call()
        
#         return data
    
#     except Exception as e:
#         return f'Error querying smart contract: {e}'

def decode_reserve_configuration(config_value):
    config = int(config_value)
    
    def get_bits(start, end):
        mask = (1 << (end - start + 1)) - 1
        return (config >> start) & mask
    
    return {
        "ltv": get_bits(0, 15)/10000,
        "liquidationThreshold": get_bits(16, 31)/10000,
        "liquidationBonus": get_bits(32, 47)/10000,
        "decimals": get_bits(48, 55),
        "reserveIsActive": bool(get_bits(56, 56)),
        "reserveIsFrozen": bool(get_bits(57, 57)),
        "borrowingEnabled": bool(get_bits(58, 58)),
        "stableRateBorrowingEnabled": bool(get_bits(59, 59)),
        "assetIsPaused": bool(get_bits(60, 60)),
        "borrowingInIsolationModeEnabled": bool(get_bits(61, 61)),
        "siloedBorrowingEnabled": bool(get_bits(62, 62)),
        "flashLoaningEnabled": bool(get_bits(63, 63)),
        "reserveFactor": get_bits(64, 79)/10000,
        "borrowCap": get_bits(80, 115),
        "supplyCap": get_bits(116, 151),
        "liquidationProtocolFee": get_bits(152, 167)/10000,
        "eModeCategoryId": get_bits(168, 175),
        "unbackedMintCap": get_bits(176, 211),
        "debtCeilingForIsolationMode": get_bits(212, 251),
        "virtualAccountingEnabled": bool(get_bits(252, 252))
    }
    
    
def get_current_price(token_address):
    """
    Fetches the current price of a token from the Coin Llama API.

    Args:
        token_address (str): The address of the token.

    Returns:
        Optional[float]: The current price of the token or None if an error occurs.
    """
    base_url = "https://coins.llama.fi/prices/current"
    url = f"{base_url}/ethereum:{token_address}"
    
    try:
        response = get(url)
        response.raise_for_status()  # Raise an exception for HTTP errors
        data = response.json()
        price_info = data.get('coins', {}).get(f'ethereum:{token_address}', {})
        return price_info.get('price')
    except Exception as e:
        print(f"Error fetching price for {token_address}: {e}")
        return None
    

def get_current_unix_timestamp() -> int:
    """
    Returns the current Unix timestamp as an integer.

    Returns:
        int: The current Unix timestamp (seconds since January 1, 1970).
    """
    return int(time.time())

# %%
asset_list = get_reserve_list()

# %%
data = []
unix_timestamp = get_current_unix_timestamp()

for asset in asset_list:
    data_dict = {}
    
    reserve_data = get_asset_data(asset[1])
    data_dict["timestamp"] = unix_timestamp
    data_dict["symbol"] = asset[0]
    data_dict["price"] = get_current_price(asset[1])
    data_dict["assetAddress"] = asset[1]
    data_dict["configuration"] = reserve_data[0][0]

    data_dict["aTokenAddress"] = reserve_data[8]
    data_dict["stableDebtTokenAddress"] = reserve_data[9]
    data_dict["variableDebtTokenAddress"] = reserve_data[10]
    
    decoded_configuration = decode_reserve_configuration(reserve_data[0][0])
    data_dict.update(decoded_configuration)
    data.append(data_dict)

print(json.dumps(data, indent=4))
# Out:
# [
#     {
#         "timestamp": 1727302495,
#         "symbol": "WETH",
#         "price": 2581.67,
#         "assetAddress": "0xC02aaA39b223FE8D0A0e5C4F27eAD9083C756Cc2",
#         "configuration": 7237005577332262213973186942896404317902510153474528182451012586290352496498,
#         "aTokenAddress": "0x4d5F47FA6A74757f35C14fD3a6Ef8E3C9BC514E8",
#         "stableDebtTokenAddress": "0x102633152313C81cD80419b6EcF66d14Ad68949A",
#         "variableDebtTokenAddress": "0xeA51d7853EEFb32b6ee06b1C12E6dcCA88Be0fFE",
#         "ltv": 0.805,
#         "liquidationThreshold": 0.83,
#         "liquidationBonus": 1.05,
#         "decimals": 18,
#         "reserveIsActive": true,
#         "reserveIsFrozen": false,
#         "borrowingEnabled": true,
#         "stableRateBorrowingEnabled": false,
#         "assetIsPaused": false,
#         "borrowingInIsolationModeEnabled": false,
#         "siloedBorrowingEnabled": false,
#         "flashLoaningEnabled": true,
#         "reserveFactor": 0.15,
#         "borrowCap": 1400000,
#         "supplyCap": 1800000,
#         "liquidationProtocolFee": 0.1,
#         "eModeCategoryId": 1,
#         "unbackedMintCap": 0,
#         "debtCeilingForIsolationMode": 0,
#         "virtualAccountingEnabled": true
#     },
#     {
#         "timestamp": 1727302495,
#         "symbol": "wstETH",
#         "price": 3044.73,
#         "assetAddress": "0x7f39C581F595B53c5cb19bD0b3f8dA6c935E2Ca0",
#         "configuration": 7237005577332262213973186942896404272210297796733577324816922171670689750698,
#         "aTokenAddress": "0x0B925eD163218f6662a35e0f0371Ac234f9E9371",
#         "stableDebtTokenAddress": "0x39739943199c0fBFe9E5f1B5B160cd73a64CB85D",
#         "variableDebtTokenAddress": "0xC96113eED8cAB59cD8A66813bCB0cEb29F06D2e4",
#         "ltv": 0.785,
#         "liquidationThreshold": 0.81,
#         "liquidationBonus": 1.06,
#         "decimals": 18,
#         "reserveIsActive": true,
#         "reserveIsFrozen": false,
#         "borrowingEnabled": true,
#         "stableRateBorrowingEnabled": false,
#         "assetIsPaused": false,
#         "borrowingInIsolationModeEnabled": false,
#         "siloedBorrowingEnabled": false,
#         "flashLoaningEnabled": true,
#         "reserveFactor": 0.05,
#         "borrowCap": 48000,
#         "supplyCap": 1250000,
#         "liquidationProtocolFee": 0.1,
#         "eModeCategoryId": 1,
#         "unbackedMintCap": 0,
#         "debtCeilingForIsolationMode": 0,
#         "virtualAccountingEnabled": true
#     },
#     {
#         "timestamp": 1727302495,
#         "symbol": "WBTC",
#         "price": 63285,
#         "assetAddress": "0x2260FAC5E5542a773Aa44fBCfeDf7C193bc2C599",
#         "configuration": 7237005577332262213973186568751985015225513804541490498545344741744385203332,
#         "aTokenAddress": "0x5Ee5bf7ae06D1Be5997A1A72006FE6C607eC6DE8",
#         "stableDebtTokenAddress": "0xA1773F1ccF6DB192Ad8FE826D15fe1d328B03284",
#         "variableDebtTokenAddress": "0x40aAbEf1aa8f0eEc637E0E7d92fbfFB2F26A8b7B",
#         "ltv": 0.73,
#         "liquidationThreshold": 0.78,
#         "liquidationBonus": 1.05,
#         "decimals": 8,
#         "reserveIsActive": true,
#         "reserveIsFrozen": false,
#         "borrowingEnabled": true,
#         "stableRateBorrowingEnabled": false,
#         "assetIsPaused": false,
#         "borrowingInIsolationModeEnabled": false,
#         "siloedBorrowingEnabled": false,
#         "flashLoaningEnabled": true,
#         "reserveFactor": 0.2,
#         "borrowCap": 28000,
#         "supplyCap": 43000,
#         "liquidationProtocolFee": 0.1,
#         "eModeCategoryId": 0,
#         "unbackedMintCap": 0,
#         "debtCeilingForIsolationMode": 0,
#         "virtualAccountingEnabled": true
#     },
#     {
#         "timestamp": 1727302495,
#         "symbol": "USDC",
#         "price": 0.99998,
#         "assetAddress": "0xA0b86991c6218b36c1d19D4a2e9Eb0cE3606eB48",
#         "configuration": 7237005577332262213973186574461162705163962882607671315109814208440733015372,
#         "aTokenAddress": "0x98C23E9d8f34FEFb1B7BD6a91B7FF122F4e16F5c",
#         "stableDebtTokenAddress": "0xB0fe3D292f4bd50De902Ba5bDF120Ad66E9d7a39",
#         "variableDebtTokenAddress": "0x72E95b8931767C79bA4EeE721354d6E99a61D004",
#         "ltv": 0.75,
#         "liquidationThreshold": 0.78,
#         "liquidationBonus": 1.045,
#         "decimals": 6,
#         "reserveIsActive": true,
#         "reserveIsFrozen": false,
#         "borrowingEnabled": true,
#         "stableRateBorrowingEnabled": false,
#         "assetIsPaused": false,
#         "borrowingInIsolationModeEnabled": true,
#         "siloedBorrowingEnabled": false,
#         "flashLoaningEnabled": true,
#         "reserveFactor": 0.1,
#         "borrowCap": 2100000000,
#         "supplyCap": 2250000000,
#         "liquidationProtocolFee": 0.2,
#         "eModeCategoryId": 0,
#         "unbackedMintCap": 0,
#         "debtCeilingForIsolationMode": 0,
#         "virtualAccountingEnabled": true
#     },
#     {
#         "timestamp": 1727302495,
#         "symbol": "DAI",
#         "price": 0.999407,
#         "assetAddress": "0x6B175474E89094C44Da98b954EedeAC495271d0F",
#         "configuration": 7237005577332262213973186574461003862418464374035535262679469658146786777244,
#         "aTokenAddress": "0x018008bfb33d285247A21d44E50697654f754e63",
#         "stableDebtTokenAddress": "0x413AdaC9E2Ef8683ADf5DDAEce8f19613d60D1bb",
#         "variableDebtTokenAddress": "0xcF8d0c70c850859266f5C338b38F9D663181C314",
#         "ltv": 0.63,
#         "liquidationThreshold": 0.77,
#         "liquidationBonus": 1.05,
#         "decimals": 18,
#         "reserveIsActive": true,
#         "reserveIsFrozen": false,
#         "borrowingEnabled": true,
#         "stableRateBorrowingEnabled": false,
#         "assetIsPaused": false,
#         "borrowingInIsolationModeEnabled": true,
#         "siloedBorrowingEnabled": false,
#         "flashLoaningEnabled": true,
#         "reserveFactor": 0.25,
#         "borrowCap": 271000000,
#         "supplyCap": 338000000,
#         "liquidationProtocolFee": 0.2,
#         "eModeCategoryId": 0,
#         "unbackedMintCap": 0,
#         "debtCeilingForIsolationMode": 0,
#         "virtualAccountingEnabled": true
#     },
#     {
#         "timestamp": 1727302495,
#         "symbol": "LINK",
#         "price": 12.2,
#         "assetAddress": "0x514910771AF9Ca656af840dff83E8264EcF986CA",
#         "configuration": 7237005577332262213973186568751986257804459629910345669476454749961209255092,
#         "aTokenAddress": "0x5E8C8A7243651DB1384C0dDfDbE39761E8e7E51a",
#         "stableDebtTokenAddress": "0x63B1129ca97D2b9F97f45670787Ac12a9dF1110a",
#         "variableDebtTokenAddress": "0x4228F8895C7dDA20227F6a5c6751b8Ebf19a6ba8",
#         "ltv": 0.53,
#         "liquidationThreshold": 0.68,
#         "liquidationBonus": 1.07,
#         "decimals": 18,
#         "reserveIsActive": true,
#         "reserveIsFrozen": false,
#         "borrowingEnabled": true,
#         "stableRateBorrowingEnabled": false,
#         "assetIsPaused": false,
#         "borrowingInIsolationModeEnabled": false,
#         "siloedBorrowingEnabled": false,
#         "flashLoaningEnabled": true,
#         "reserveFactor": 0.2,
#         "borrowCap": 13000000,
#         "supplyCap": 15000000,
#         "liquidationProtocolFee": 0.1,
#         "eModeCategoryId": 0,
#         "unbackedMintCap": 0,
#         "debtCeilingForIsolationMode": 0,
#         "virtualAccountingEnabled": true
#     },
#     {
#         "timestamp": 1727302495,
#         "symbol": "AAVE",
#         "price": 165.11,
#         "assetAddress": "0x7Fc66500c84A76Ad7e9c93437bFc5Ac33E2DDaE9",
#         "configuration": 7237005577332262213973186568751985165345200578466576934766848061255394269640,
#         "aTokenAddress": "0xA700b4eB416Be35b2911fd5Dee80678ff64fF6C9",
#         "stableDebtTokenAddress": "0x268497bF083388B1504270d0E717222d3A87D6F2",
#         "variableDebtTokenAddress": "0xBae535520Abd9f8C85E58929e0006A2c8B372F74",
#         "ltv": 0.66,
#         "liquidationThreshold": 0.73,
#         "liquidationBonus": 1.075,
#         "decimals": 18,
#         "reserveIsActive": true,
#         "reserveIsFrozen": false,
#         "borrowingEnabled": false,
#         "stableRateBorrowingEnabled": false,
#         "assetIsPaused": false,
#         "borrowingInIsolationModeEnabled": false,
#         "siloedBorrowingEnabled": false,
#         "flashLoaningEnabled": false,
#         "reserveFactor": 0.0,
#         "borrowCap": 0,
#         "supplyCap": 1850000,
#         "liquidationProtocolFee": 0.1,
#         "eModeCategoryId": 0,
#         "unbackedMintCap": 0,
#         "debtCeilingForIsolationMode": 0,
#         "virtualAccountingEnabled": true
#     },
#     {
#         "timestamp": 1727302495,
#         "symbol": "cbETH",
#         "price": 2787.93,
#         "assetAddress": "0xBe9895146f7AF43049ca1c1AE358B0541Ea49704",
#         "configuration": 7237005577332262213973186942896404173348965610175332278668589047307230780698,
#         "aTokenAddress": "0x977b6fc5dE62598B08C85AC8Cf2b745874E8b78c",
#         "stableDebtTokenAddress": "0x82bE6012cea6D147B968eBAea5ceEcF6A5b4F493",
#         "variableDebtTokenAddress": "0x0c91bcA95b5FE69164cE583A2ec9429A569798Ed",
#         "ltv": 0.745,
#         "liquidationThreshold": 0.77,
#         "liquidationBonus": 1.075,
#         "decimals": 18,
#         "reserveIsActive": true,
#         "reserveIsFrozen": false,
#         "borrowingEnabled": true,
#         "stableRateBorrowingEnabled": false,
#         "assetIsPaused": false,
#         "borrowingInIsolationModeEnabled": false,
#         "siloedBorrowingEnabled": false,
#         "flashLoaningEnabled": true,
#         "reserveFactor": 0.15,
#         "borrowCap": 2400,
#         "supplyCap": 60000,
#         "liquidationProtocolFee": 0.1,
#         "eModeCategoryId": 1,
#         "unbackedMintCap": 0,
#         "debtCeilingForIsolationMode": 0,
#         "virtualAccountingEnabled": true
#     },
#     {
#         "timestamp": 1727302495,
#         "symbol": "USDT",
#         "price": 0.99944,
#         "assetAddress": "0xdAC17F958D2ee523a2206206994597C13D831ec7",
#         "configuration": 7237005577332262213973186568752192703527557679023914501491526749220146519372,
#         "aTokenAddress": "0x23878914EFE38d27C4D67Ab83ed1b93A74D4086a",
#         "stableDebtTokenAddress": "0x822Fa72Df1F229C3900f5AD6C3Fa2C424D691622",
#         "variableDebtTokenAddress": "0x6df1C1E379bC5a00a7b4C6e67A203333772f45A8",
#         "ltv": 0.75,
#         "liquidationThreshold": 0.78,
#         "liquidationBonus": 1.045,
#         "decimals": 6,
#         "reserveIsActive": true,
#         "reserveIsFrozen": false,
#         "borrowingEnabled": true,
#         "stableRateBorrowingEnabled": false,
#         "assetIsPaused": false,
#         "borrowingInIsolationModeEnabled": true,
#         "siloedBorrowingEnabled": false,
#         "flashLoaningEnabled": true,
#         "reserveFactor": 0.1,
#         "borrowCap": 2250000000,
#         "supplyCap": 2500000000,
#         "liquidationProtocolFee": 0.1,
#         "eModeCategoryId": 0,
#         "unbackedMintCap": 0,
#         "debtCeilingForIsolationMode": 0,
#         "virtualAccountingEnabled": true
#     },
#     {
#         "timestamp": 1727302495,
#         "symbol": "rETH",
#         "price": 2885.23,
#         "assetAddress": "0xae78736Cd615f374D3085123A210448E74Fc6393",
#         "configuration": 7237005577332262213973186942896404175841268102292359494132753055467940617498,
#         "aTokenAddress": "0xCc9EE9483f662091a1de4795249E24aC0aC2630f",
#         "stableDebtTokenAddress": "0x1d1906f909CAe494c7441604DAfDDDbD0485A925",
#         "variableDebtTokenAddress": "0xae8593DD575FE29A9745056aA91C4b746eee62C8",
#         "ltv": 0.745,
#         "liquidationThreshold": 0.77,
#         "liquidationBonus": 1.075,
#         "decimals": 18,
#         "reserveIsActive": true,
#         "reserveIsFrozen": false,
#         "borrowingEnabled": true,
#         "stableRateBorrowingEnabled": false,
#         "assetIsPaused": false,
#         "borrowingInIsolationModeEnabled": false,
#         "siloedBorrowingEnabled": false,
#         "flashLoaningEnabled": true,
#         "reserveFactor": 0.15,
#         "borrowCap": 19200,
#         "supplyCap": 90000,
#         "liquidationProtocolFee": 0.1,
#         "eModeCategoryId": 1,
#         "unbackedMintCap": 0,
#         "debtCeilingForIsolationMode": 0,
#         "virtualAccountingEnabled": true
#     },
#     {
#         "timestamp": 1727302495,
#         "symbol": "LUSD",
#         "price": 0.999316,
#         "assetAddress": "0x5f98805A4E8be255a32880FDeC7F6728C6568bA0",
#         "configuration": 7237005577332262213973186568751986507034708833537442740869438520930468102144,
#         "aTokenAddress": "0x3Fe6a295459FAe07DF8A0ceCC36F37160FE86AA9",
#         "stableDebtTokenAddress": "0x37A6B708FDB1483C231961b9a7F145261E815fc3",
#         "variableDebtTokenAddress": "0x33652e48e4B74D18520f11BfE58Edd2ED2cEc5A2",
#         "ltv": 0.0,
#         "liquidationThreshold": 0.77,
#         "liquidationBonus": 1.045,
#         "decimals": 18,
#         "reserveIsActive": true,
#         "reserveIsFrozen": false,
#         "borrowingEnabled": true,
#         "stableRateBorrowingEnabled": false,
#         "assetIsPaused": false,
#         "borrowingInIsolationModeEnabled": true,
#         "siloedBorrowingEnabled": false,
#         "flashLoaningEnabled": true,
#         "reserveFactor": 0.2,
#         "borrowCap": 8000000,
#         "supplyCap": 18000000,
#         "liquidationProtocolFee": 0.1,
#         "eModeCategoryId": 0,
#         "unbackedMintCap": 0,
#         "debtCeilingForIsolationMode": 0,
#         "virtualAccountingEnabled": true
#     },
#     {
#         "timestamp": 1727302495,
#         "symbol": "CRV",
#         "price": 0.303834,
#         "assetAddress": "0xD533a949740bb3306d119CC777fa900bA034cd52",
#         "configuration": 7237663779155190696390048556425008907237828634821456645045138708659257478572,
#         "aTokenAddress": "0x7B95Ec873268a6BFC6427e7a28e396Db9D0ebc65",
#         "stableDebtTokenAddress": "0x90D9CD005E553111EB8C9c31Abe9706a186b6048",
#         "variableDebtTokenAddress": "0x1b7D3F4b3c032a5AE656e30eeA4e8E1Ba376068F",
#         "ltv": 0.35,
#         "liquidationThreshold": 0.41,
#         "liquidationBonus": 1.083,
#         "decimals": 18,
#         "reserveIsActive": true,
#         "reserveIsFrozen": false,
#         "borrowingEnabled": true,
#         "stableRateBorrowingEnabled": false,
#         "assetIsPaused": false,
#         "borrowingInIsolationModeEnabled": false,
#         "siloedBorrowingEnabled": false,
#         "flashLoaningEnabled": true,
#         "reserveFactor": 0.35,
#         "borrowCap": 3500000,
#         "supplyCap": 11500000,
#         "liquidationProtocolFee": 0.1,
#         "eModeCategoryId": 0,
#         "unbackedMintCap": 0,
#         "debtCeilingForIsolationMode": 100000000,
#         "virtualAccountingEnabled": true
#     },
#     {
#         "timestamp": 1727302495,
#         "symbol": "MKR",
#         "price": 1561.01,
#         "assetAddress": "0x9f8F72aA9304c8B593d555F12eF6589cC3A579A2",
#         "configuration": 7244903999207404002975530420828260295946357567065651969905045434202492246372,
#         "aTokenAddress": "0x8A458A9dc9048e005d22849F470891b840296619",
#         "stableDebtTokenAddress": "0x0496372BE7e426D28E89DEBF01f19F014d5938bE",
#         "variableDebtTokenAddress": "0x6Efc73E54E41b27d2134fF9f98F15550f30DF9B1",
#         "ltv": 0.65,
#         "liquidationThreshold": 0.7,
#         "liquidationBonus": 1.085,
#         "decimals": 18,
#         "reserveIsActive": true,
#         "reserveIsFrozen": false,
#         "borrowingEnabled": true,
#         "stableRateBorrowingEnabled": false,
#         "assetIsPaused": false,
#         "borrowingInIsolationModeEnabled": false,
#         "siloedBorrowingEnabled": false,
#         "flashLoaningEnabled": true,
#         "reserveFactor": 0.2,
#         "borrowCap": 1980,
#         "supplyCap": 22500,
#         "liquidationProtocolFee": 0.1,
#         "eModeCategoryId": 0,
#         "unbackedMintCap": 0,
#         "debtCeilingForIsolationMode": 1200000000,
#         "virtualAccountingEnabled": true
#     },
#     {
#         "timestamp": 1727302495,
#         "symbol": "SNX",
#         "price": 1.68,
#         "assetAddress": "0xC011a73ee8576Fb46F5E1c5751cA3B9Fe0af2a6F",
#         "configuration": 7239638384623976143640634519444077146306559757909621049756560431657672512292,
#         "aTokenAddress": "0xC7B4c17861357B8ABB91F25581E7263E08DCB59c",
#         "stableDebtTokenAddress": "0x478E1ec1A2BeEd94c1407c951E4B9e22d53b2501",
#         "variableDebtTokenAddress": "0x8d0de040e8aAd872eC3c33A3776dE9152D3c34ca",
#         "ltv": 0.49,
#         "liquidationThreshold": 0.65,
#         "liquidationBonus": 1.085,
#         "decimals": 18,
#         "reserveIsActive": true,
#         "reserveIsFrozen": false,
#         "borrowingEnabled": true,
#         "stableRateBorrowingEnabled": false,
#         "assetIsPaused": false,
#         "borrowingInIsolationModeEnabled": false,
#         "siloedBorrowingEnabled": false,
#         "flashLoaningEnabled": true,
#         "reserveFactor": 0.35,
#         "borrowCap": 150000,
#         "supplyCap": 4500000,
#         "liquidationProtocolFee": 0.1,
#         "eModeCategoryId": 0,
#         "unbackedMintCap": 0,
#         "debtCeilingForIsolationMode": 400000000,
#         "virtualAccountingEnabled": true
#     },
#     {
#         "timestamp": 1727302495,
#         "symbol": "BAL",
#         "price": 2.06,
#         "assetAddress": "0xba100000625a3754423978a60c9317c58a424e3D",
#         "configuration": 7238914362618754812982086333003752369006490906221160504302682702905544021572,
#         "aTokenAddress": "0x2516E7B3F76294e03C42AA4c5b5b4DCE9C436fB8",
#         "stableDebtTokenAddress": "0xB368d45aaAa07ee2c6275Cb320D140b22dE43CDD",
#         "variableDebtTokenAddress": "0x3D3efceb4Ff0966D34d9545D3A2fa2dcdBf451f2",
#         "ltv": 0.57,
#         "liquidationThreshold": 0.59,
#         "liquidationBonus": 1.083,
#         "decimals": 18,
#         "reserveIsActive": true,
#         "reserveIsFrozen": false,
#         "borrowingEnabled": true,
#         "stableRateBorrowingEnabled": false,
#         "assetIsPaused": false,
#         "borrowingInIsolationModeEnabled": false,
#         "siloedBorrowingEnabled": false,
#         "flashLoaningEnabled": true,
#         "reserveFactor": 0.2,
#         "borrowCap": 1000000,
#         "supplyCap": 10000000,
#         "liquidationProtocolFee": 0.1,
#         "eModeCategoryId": 0,
#         "unbackedMintCap": 0,
#         "debtCeilingForIsolationMode": 290000000,
#         "virtualAccountingEnabled": true
#     },
#     {
#         "timestamp": 1727302495,
#         "symbol": "UNI",
#         "price": 6.85,
#         "assetAddress": "0x1f9840a85d5aF5bf1D1762F925BDADdC4201F984",
#         "configuration": 7248195008322046415059840359193375327394095116349901256662519706348792846692,
#         "aTokenAddress": "0xF6D2224916DDFbbab6e6bd0D1B7034f4Ae0CaB18",
#         "stableDebtTokenAddress": "0x2FEc76324A0463c46f32e74A86D1cf94C02158DC",
#         "variableDebtTokenAddress": "0xF64178Ebd2E2719F2B1233bCb5Ef6DB4bCc4d09a",
#         "ltv": 0.65,
#         "liquidationThreshold": 0.74,
#         "liquidationBonus": 1.1,
#         "decimals": 18,
#         "reserveIsActive": true,
#         "reserveIsFrozen": false,
#         "borrowingEnabled": true,
#         "stableRateBorrowingEnabled": false,
#         "assetIsPaused": false,
#         "borrowingInIsolationModeEnabled": false,
#         "siloedBorrowingEnabled": false,
#         "flashLoaningEnabled": true,
#         "reserveFactor": 0.2,
#         "borrowCap": 330000,
#         "supplyCap": 4000000,
#         "liquidationProtocolFee": 0.1,
#         "eModeCategoryId": 0,
#         "unbackedMintCap": 0,
#         "debtCeilingForIsolationMode": 1700000000,
#         "virtualAccountingEnabled": true
#     },
#     {
#         "timestamp": 1727302495,
#         "symbol": "LDO",
#         "price": 1.25,
#         "assetAddress": "0x5A98FcBEA516Cf06857215779Fd812CA3beF1B32",
#         "configuration": 7241942091004225832099651476299657727782159667703905088082676196120308748192,
#         "aTokenAddress": "0x9A44fd41566876A39655f74971a3A6eA0a17a454",
#         "stableDebtTokenAddress": "0xa0a5bF5781Aeb548db9d4226363B9e89287C5FD2",
#         "variableDebtTokenAddress": "0xc30808705C01289A3D306ca9CAB081Ba9114eC82",
#         "ltv": 0.4,
#         "liquidationThreshold": 0.5,
#         "liquidationBonus": 1.09,
#         "decimals": 18,
#         "reserveIsActive": true,
#         "reserveIsFrozen": false,
#         "borrowingEnabled": true,
#         "stableRateBorrowingEnabled": false,
#         "assetIsPaused": false,
#         "borrowingInIsolationModeEnabled": false,
#         "siloedBorrowingEnabled": false,
#         "flashLoaningEnabled": true,
#         "reserveFactor": 0.2,
#         "borrowCap": 1500000,
#         "supplyCap": 8000000,
#         "liquidationProtocolFee": 0.1,
#         "eModeCategoryId": 0,
#         "unbackedMintCap": 0,
#         "debtCeilingForIsolationMode": 750000000,
#         "virtualAccountingEnabled": true
#     },
#     {
#         "timestamp": 1727302495,
#         "symbol": "ENS",
#         "price": 19.28753340637693,
#         "assetAddress": "0xC18360217D8F7Ab5e7c516566761Ea12Ce7F9D72",
#         "configuration": 7239572564441683295398948320676774603056111238670287669270477364735244504892,
#         "aTokenAddress": "0x545bD6c032eFdde65A377A6719DEF2796C8E0f2e",
#         "stableDebtTokenAddress": "0x7617d02E311CdE347A0cb45BB7DF2926BBaf5347",
#         "variableDebtTokenAddress": "0xd180D7fdD4092f07428eFE801E17BC03576b3192",
#         "ltv": 0.39,
#         "liquidationThreshold": 0.49,
#         "liquidationBonus": 1.08,
#         "decimals": 18,
#         "reserveIsActive": true,
#         "reserveIsFrozen": false,
#         "borrowingEnabled": true,
#         "stableRateBorrowingEnabled": false,
#         "assetIsPaused": false,
#         "borrowingInIsolationModeEnabled": false,
#         "siloedBorrowingEnabled": false,
#         "flashLoaningEnabled": true,
#         "reserveFactor": 0.2,
#         "borrowCap": 40000,
#         "supplyCap": 1500000,
#         "liquidationProtocolFee": 0.1,
#         "eModeCategoryId": 0,
#         "unbackedMintCap": 0,
#         "debtCeilingForIsolationMode": 390000000,
#         "virtualAccountingEnabled": true
#     },
#     {
#         "timestamp": 1727302495,
#         "symbol": "1INCH",
#         "price": 0.295948,
#         "assetAddress": "0x111111111117dC0aa78b770fA6A738034120C302",
#         "configuration": 7239967485535440384849065513280590734864674587685562855040293771882277901892,
#         "aTokenAddress": "0x71Aef7b30728b9BB371578f36c5A1f1502a5723e",
#         "stableDebtTokenAddress": "0x4b62bFAff61AB3985798e5202D2d167F567D0BCD",
#         "variableDebtTokenAddress": "0xA38fCa8c6Bf9BdA52E76EB78f08CaA3BE7c5A970",
#         "ltv": 0.57,
#         "liquidationThreshold": 0.67,
#         "liquidationBonus": 1.075,
#         "decimals": 18,
#         "reserveIsActive": true,
#         "reserveIsFrozen": false,
#         "borrowingEnabled": true,
#         "stableRateBorrowingEnabled": false,
#         "assetIsPaused": false,
#         "borrowingInIsolationModeEnabled": false,
#         "siloedBorrowingEnabled": false,
#         "flashLoaningEnabled": true,
#         "reserveFactor": 0.2,
#         "borrowCap": 475200,
#         "supplyCap": 30000000,
#         "liquidationProtocolFee": 0.1,
#         "eModeCategoryId": 0,
#         "unbackedMintCap": 0,
#         "debtCeilingForIsolationMode": 450000000,
#         "virtualAccountingEnabled": true
#     },
#     {
#         "timestamp": 1727302495,
#         "symbol": "FRAX",
#         "price": 0.996258,
#         "assetAddress": "0x853d955aCEf822Db058eb8505911ED77F175b99e",
#         "configuration": 7243587595561547038141806445482215659824390572163954169315220010921562734592,
#         "aTokenAddress": "0xd4e245848d6E1220DBE62e155d89fa327E43CB06",
#         "stableDebtTokenAddress": "0x219640546c0DFDDCb9ab3bcdA89B324e0a376367",
#         "variableDebtTokenAddress": "0x88B8358F5BC87c2D7E116cCA5b65A9eEb2c5EA3F",
#         "ltv": 0.0,
#         "liquidationThreshold": 0.72,
#         "liquidationBonus": 1.06,
#         "decimals": 18,
#         "reserveIsActive": true,
#         "reserveIsFrozen": false,
#         "borrowingEnabled": true,
#         "stableRateBorrowingEnabled": false,
#         "assetIsPaused": false,
#         "borrowingInIsolationModeEnabled": false,
#         "siloedBorrowingEnabled": false,
#         "flashLoaningEnabled": true,
#         "reserveFactor": 0.2,
#         "borrowCap": 12000000,
#         "supplyCap": 15000000,
#         "liquidationProtocolFee": 0.1,
#         "eModeCategoryId": 0,
#         "unbackedMintCap": 0,
#         "debtCeilingForIsolationMode": 1000000000,
#         "virtualAccountingEnabled": true
#     },
#     {
#         "timestamp": 1727302495,
#         "symbol": "GHO",
#         "price": 1.001,
#         "assetAddress": "0x40D16FC0246aD3160Ccc09B8D0D3A2cD28aE6C2f",
#         "configuration": 181338872942194741560446170431488,
#         "aTokenAddress": "0x00907f9921424583e7ffBfEdf84F92B7B2Be4977",
#         "stableDebtTokenAddress": "0x3f3DF7266dA30102344A813F1a3D07f5F041B5AC",
#         "variableDebtTokenAddress": "0x786dBff3f1292ae8F92ea68Cf93c30b34B1ed04B",
#         "ltv": 0.0,
#         "liquidationThreshold": 0.0,
#         "liquidationBonus": 0.0,
#         "decimals": 18,
#         "reserveIsActive": true,
#         "reserveIsFrozen": false,
#         "borrowingEnabled": true,
#         "stableRateBorrowingEnabled": false,
#         "assetIsPaused": false,
#         "borrowingInIsolationModeEnabled": false,
#         "siloedBorrowingEnabled": false,
#         "flashLoaningEnabled": false,
#         "reserveFactor": 0.0,
#         "borrowCap": 150000000,
#         "supplyCap": 0,
#         "liquidationProtocolFee": 0.0,
#         "eModeCategoryId": 0,
#         "unbackedMintCap": 0,
#         "debtCeilingForIsolationMode": 0,
#         "virtualAccountingEnabled": false
#     },
#     {
#         "timestamp": 1727302495,
#         "symbol": "RPL",
#         "price": 11.09,
#         "assetAddress": "0xD33526068D116cE69F19A9ee46F0bd304F21A51f",
#         "configuration": 7237005577332262213973186563042994310613843820915081526626361126541477281792,
#         "aTokenAddress": "0xB76CF92076adBF1D9C39294FA8e7A67579FDe357",
#         "stableDebtTokenAddress": "0x41e330fd8F7eA31E2e8F02cC0C9392D1403597B4",
#         "variableDebtTokenAddress": "0x8988ECA19D502fd8b9CCd03fA3bD20a6f599bc2A",
#         "ltv": 0.0,
#         "liquidationThreshold": 0.0,
#         "liquidationBonus": 0.0,
#         "decimals": 18,
#         "reserveIsActive": true,
#         "reserveIsFrozen": false,
#         "borrowingEnabled": true,
#         "stableRateBorrowingEnabled": false,
#         "assetIsPaused": false,
#         "borrowingInIsolationModeEnabled": false,
#         "siloedBorrowingEnabled": false,
#         "flashLoaningEnabled": true,
#         "reserveFactor": 0.2,
#         "borrowCap": 500000,
#         "supplyCap": 840000,
#         "liquidationProtocolFee": 0.0,
#         "eModeCategoryId": 0,
#         "unbackedMintCap": 0,
#         "debtCeilingForIsolationMode": 0,
#         "virtualAccountingEnabled": true
#     },
#     {
#         "timestamp": 1727302495,
#         "symbol": "sDAI",
#         "price": 1.1093991829297318,
#         "assetAddress": "0x83F20F44975D03b1b09e64809B757c47f942BEeA",
#         "configuration": 7237005577332262213973186568752013257748123995297978373066899191830293257548,
#         "aTokenAddress": "0x4C612E3B15b96Ff9A6faED838F8d07d479a8dD4c",
#         "stableDebtTokenAddress": "0x48Bc45f084988bC01933EA93EeFfEBC0416534f6",
#         "variableDebtTokenAddress": "0x8Db9D35e117d8b93C6Ca9b644b25BaD5d9908141",
#         "ltv": 0.75,
#         "liquidationThreshold": 0.78,
#         "liquidationBonus": 1.045,
#         "decimals": 18,
#         "reserveIsActive": true,
#         "reserveIsFrozen": false,
#         "borrowingEnabled": false,
#         "stableRateBorrowingEnabled": false,
#         "assetIsPaused": false,
#         "borrowingInIsolationModeEnabled": false,
#         "siloedBorrowingEnabled": false,
#         "flashLoaningEnabled": true,
#         "reserveFactor": 0.2,
#         "borrowCap": 0,
#         "supplyCap": 340000000,
#         "liquidationProtocolFee": 0.1,
#         "eModeCategoryId": 0,
#         "unbackedMintCap": 0,
#         "debtCeilingForIsolationMode": 0,
#         "virtualAccountingEnabled": true
#     },
#     {
#         "timestamp": 1727302495,
#         "symbol": "STG",
#         "price": 0.344505,
#         "assetAddress": "0xAf5191B0De278C7286d6C7CC6ab6BB8A73bA2Cd6",
#         "configuration": 7238980182801047661223772531771054663026690218315422650649544947538167332864,
#         "aTokenAddress": "0x1bA9843bD4327c6c77011406dE5fA8749F7E3479",
#         "stableDebtTokenAddress": "0xc3115D0660b93AeF10F298886ae22E3Dd477E482",
#         "variableDebtTokenAddress": "0x655568bDd6168325EC7e58Bf39b21A856F906Dc2",
#         "ltv": 0.0,
#         "liquidationThreshold": 0.37,
#         "liquidationBonus": 1.1,
#         "decimals": 18,
#         "reserveIsActive": true,
#         "reserveIsFrozen": true,
#         "borrowingEnabled": true,
#         "stableRateBorrowingEnabled": false,
#         "assetIsPaused": false,
#         "borrowingInIsolationModeEnabled": false,
#         "siloedBorrowingEnabled": false,
#         "flashLoaningEnabled": true,
#         "reserveFactor": 0.2,
#         "borrowCap": 3200000,
#         "supplyCap": 10000000,
#         "liquidationProtocolFee": 0.1,
#         "eModeCategoryId": 0,
#         "unbackedMintCap": 0,
#         "debtCeilingForIsolationMode": 300000000,
#         "virtualAccountingEnabled": true
#     },
#     {
#         "timestamp": 1727302495,
#         "symbol": "KNC",
#         "price": 0.508859,
#         "assetAddress": "0xdeFA4e8a7bcBA345F687a2f1456F5Edd9CE97202",
#         "configuration": 7237663779155190696390048556425008051547306344473747103763289758216848932864,
#         "aTokenAddress": "0x5b502e3796385E1e9755d7043B9C945C3aCCeC9C",
#         "stableDebtTokenAddress": "0xdfEE0C9eA1309cB9611F33972E72a72166fcF548",
#         "variableDebtTokenAddress": "0x253127Ffc04981cEA8932F406710661c2f2c3fD2",
#         "ltv": 0.0,
#         "liquidationThreshold": 0.37,
#         "liquidationBonus": 1.1,
#         "decimals": 18,
#         "reserveIsActive": true,
#         "reserveIsFrozen": true,
#         "borrowingEnabled": true,
#         "stableRateBorrowingEnabled": false,
#         "assetIsPaused": false,
#         "borrowingInIsolationModeEnabled": false,
#         "siloedBorrowingEnabled": false,
#         "flashLoaningEnabled": true,
#         "reserveFactor": 0.2,
#         "borrowCap": 350000,
#         "supplyCap": 1200000,
#         "liquidationProtocolFee": 0.1,
#         "eModeCategoryId": 0,
#         "unbackedMintCap": 0,
#         "debtCeilingForIsolationMode": 100000000,
#         "virtualAccountingEnabled": true
#     },
#     {
#         "timestamp": 1727302495,
#         "symbol": "FXS",
#         "price": 1.97,
#         "assetAddress": "0x3432B6A60D23Ca0dFCa7761B7ab56459D9C964D0",
#         "configuration": 7239638384623976143640634519444076872153285627488328883207015505551558180864,
#         "aTokenAddress": "0x82F9c5ad306BBa1AD0De49bB5FA6F01bf61085ef",
#         "stableDebtTokenAddress": "0x61dFd349140C239d3B61fEe203Efc811b518a317",
#         "variableDebtTokenAddress": "0x68e9f0aD4e6f8F5DB70F6923d4d6d5b225B83b16",
#         "ltv": 0.0,
#         "liquidationThreshold": 0.42,
#         "liquidationBonus": 1.1,
#         "decimals": 18,
#         "reserveIsActive": true,
#         "reserveIsFrozen": true,
#         "borrowingEnabled": true,
#         "stableRateBorrowingEnabled": false,
#         "assetIsPaused": false,
#         "borrowingInIsolationModeEnabled": false,
#         "siloedBorrowingEnabled": false,
#         "flashLoaningEnabled": true,
#         "reserveFactor": 0.2,
#         "borrowCap": 330000,
#         "supplyCap": 1200000,
#         "liquidationProtocolFee": 0.1,
#         "eModeCategoryId": 0,
#         "unbackedMintCap": 0,
#         "debtCeilingForIsolationMode": 400000000,
#         "virtualAccountingEnabled": true
#     },
#     {
#         "timestamp": 1727302495,
#         "symbol": "crvUSD",
#         "price": 0.998484,
#         "assetAddress": "0xf939E0A03FB07F59A73314E73794Be0E57ac1b4E",
#         "configuration": 7237005577332262213973186563042994656213122727411060102398711075133867425792,
#         "aTokenAddress": "0xb82fa9f31612989525992FCfBB09AB22Eff5c85A",
#         "stableDebtTokenAddress": "0xb55C604075D79486b8A329c396Fc711Be54B5330",
#         "variableDebtTokenAddress": "0x028f7886F3e937f8479efaD64f31B3fE1119857a",
#         "ltv": 0.0,
#         "liquidationThreshold": 0.0,
#         "liquidationBonus": 0.0,
#         "decimals": 18,
#         "reserveIsActive": true,
#         "reserveIsFrozen": false,
#         "borrowingEnabled": true,
#         "stableRateBorrowingEnabled": false,
#         "assetIsPaused": false,
#         "borrowingInIsolationModeEnabled": false,
#         "siloedBorrowingEnabled": false,
#         "flashLoaningEnabled": true,
#         "reserveFactor": 0.1,
#         "borrowCap": 2500000,
#         "supplyCap": 5000000,
#         "liquidationProtocolFee": 0.0,
#         "eModeCategoryId": 0,
#         "unbackedMintCap": 0,
#         "debtCeilingForIsolationMode": 0,
#         "virtualAccountingEnabled": true
#     },
#     {
#         "timestamp": 1727302495,
#         "symbol": "PYUSD",
#         "price": 0.999261,
#         "assetAddress": "0x6c3ea9036406852006290770BEdFcAbA0e23A0e8",
#         "configuration": 7237005577332262213973186563042999225434358293065498020147848933959186513920,
#         "aTokenAddress": "0x0C0d01AbF3e6aDfcA0989eBbA9d6e85dD58EaB1E",
#         "stableDebtTokenAddress": "0x5B393DB4c72B1Bd82CE2834F6485d61b137Bc7aC",
#         "variableDebtTokenAddress": "0x57B67e4DE077085Fd0AF2174e9c14871BE664546",
#         "ltv": 0.0,
#         "liquidationThreshold": 0.0,
#         "liquidationBonus": 0.0,
#         "decimals": 6,
#         "reserveIsActive": true,
#         "reserveIsFrozen": false,
#         "borrowingEnabled": true,
#         "stableRateBorrowingEnabled": false,
#         "assetIsPaused": false,
#         "borrowingInIsolationModeEnabled": false,
#         "siloedBorrowingEnabled": false,
#         "flashLoaningEnabled": true,
#         "reserveFactor": 0.2,
#         "borrowCap": 48000000,
#         "supplyCap": 60000000,
#         "liquidationProtocolFee": 0.0,
#         "eModeCategoryId": 0,
#         "unbackedMintCap": 0,
#         "debtCeilingForIsolationMode": 0,
#         "virtualAccountingEnabled": true
#     },
#     {
#         "timestamp": 1727302495,
#         "symbol": "weETH",
#         "price": 2705.669480348826,
#         "assetAddress": "0xCd5fE23C85820F7B72D0926FC9b05b43E359b7ee",
#         "configuration": 7237005577332262213973186942896404246041121629901802875391620602439156898898,
#         "aTokenAddress": "0xBdfa7b7893081B35Fb54027489e2Bc7A38275129",
#         "stableDebtTokenAddress": "0xBad6eF8e76E26F39e985474aD0974FDcabF85d37",
#         "variableDebtTokenAddress": "0x77ad9BF13a52517AD698D65913e8D381300c8Bf3",
#         "ltv": 0.725,
#         "liquidationThreshold": 0.75,
#         "liquidationBonus": 1.075,
#         "decimals": 18,
#         "reserveIsActive": true,
#         "reserveIsFrozen": false,
#         "borrowingEnabled": true,
#         "stableRateBorrowingEnabled": false,
#         "assetIsPaused": false,
#         "borrowingInIsolationModeEnabled": false,
#         "siloedBorrowingEnabled": false,
#         "flashLoaningEnabled": true,
#         "reserveFactor": 0.45,
#         "borrowCap": 200000,
#         "supplyCap": 935000,
#         "liquidationProtocolFee": 0.1,
#         "eModeCategoryId": 1,
#         "unbackedMintCap": 0,
#         "debtCeilingForIsolationMode": 0,
#         "virtualAccountingEnabled": true
#     },
#     {
#         "timestamp": 1727302495,
#         "symbol": "osETH",
#         "price": 2652.3676349506545,
#         "assetAddress": "0xf1C9acDc66974dFB6dEcB12aA385b9cD01190E38",
#         "configuration": 7237005577332262213973186942896404169195128123345777679696731503086552226898,
#         "aTokenAddress": "0x927709711794F3De5DdBF1D176bEE2D55Ba13c21",
#         "stableDebtTokenAddress": "0x48Fa27f511F40d16f9E7C913e9388d52d95bC6d2",
#         "variableDebtTokenAddress": "0x8838eefF2af391863E1Bb8b1dF563F86743a8470",
#         "ltv": 0.725,
#         "liquidationThreshold": 0.75,
#         "liquidationBonus": 1.075,
#         "decimals": 18,
#         "reserveIsActive": true,
#         "reserveIsFrozen": false,
#         "borrowingEnabled": true,
#         "stableRateBorrowingEnabled": false,
#         "assetIsPaused": false,
#         "borrowingInIsolationModeEnabled": false,
#         "siloedBorrowingEnabled": false,
#         "flashLoaningEnabled": true,
#         "reserveFactor": 0.15,
#         "borrowCap": 1000,
#         "supplyCap": 10000,
#         "liquidationProtocolFee": 0.1,
#         "eModeCategoryId": 1,
#         "unbackedMintCap": 0,
#         "debtCeilingForIsolationMode": 0,
#         "virtualAccountingEnabled": true
#     },
#     {
#         "timestamp": 1727302495,
#         "symbol": "USDe",
#         "price": 0.998731,
#         "assetAddress": "0x4c9EDD5852cd905f086C759E8383e09bff1E68B3",
#         "configuration": 7269915668478686334816285952403141990962836802999237709821967847209841728544,
#         "aTokenAddress": "0x4F5923Fc5FD4a93352581b38B7cD26943012DECF",
#         "stableDebtTokenAddress": "0x43Cc8AD0c223b38D9c04802bB184A2D97e497D38",
#         "variableDebtTokenAddress": "0x015396E1F286289aE23a762088E863b3ec465145",
#         "ltv": 0.72,
#         "liquidationThreshold": 0.75,
#         "liquidationBonus": 1.085,
#         "decimals": 18,
#         "reserveIsActive": true,
#         "reserveIsFrozen": false,
#         "borrowingEnabled": true,
#         "stableRateBorrowingEnabled": false,
#         "assetIsPaused": false,
#         "borrowingInIsolationModeEnabled": true,
#         "siloedBorrowingEnabled": false,
#         "flashLoaningEnabled": true,
#         "reserveFactor": 0.25,
#         "borrowCap": 110000000,
#         "supplyCap": 120000000,
#         "liquidationProtocolFee": 0.1,
#         "eModeCategoryId": 0,
#         "unbackedMintCap": 0,
#         "debtCeilingForIsolationMode": 5000000000,
#         "virtualAccountingEnabled": true
#     },
#     {
#         "timestamp": 1727302495,
#         "symbol": "ETHx",
#         "price": 2690.54,
#         "assetAddress": "0xA35b1B31Ce002FBF2058D22F30f95D405200A15b",
#         "configuration": 7237005577332262213973186942896404169195128123344955610139393555247765134618,
#         "aTokenAddress": "0x1c0E06a0b1A4c160c17545FF2A951bfcA57C0002",
#         "stableDebtTokenAddress": "0xBDfa7DE5CF7a7DdE4F023Cac842BF520fcF5395C",
#         "variableDebtTokenAddress": "0x08a8Dc81AeA67F84745623aC6c72CDA3967aab8b",
#         "ltv": 0.745,
#         "liquidationThreshold": 0.77,
#         "liquidationBonus": 1.075,
#         "decimals": 18,
#         "reserveIsActive": true,
#         "reserveIsFrozen": false,
#         "borrowingEnabled": true,
#         "stableRateBorrowingEnabled": false,
#         "assetIsPaused": false,
#         "borrowingInIsolationModeEnabled": false,
#         "siloedBorrowingEnabled": false,
#         "flashLoaningEnabled": true,
#         "reserveFactor": 0.15,
#         "borrowCap": 320,
#         "supplyCap": 10000,
#         "liquidationProtocolFee": 0.1,
#         "eModeCategoryId": 1,
#         "unbackedMintCap": 0,
#         "debtCeilingForIsolationMode": 0,
#         "virtualAccountingEnabled": true
#     },
#     {
#         "timestamp": 1727302495,
#         "symbol": "sUSDe",
#         "price": 1.100570567727277,
#         "assetAddress": "0x9D39A5DE30e57443BfF2A8307A4256c8797A3497",
#         "configuration": 7263333650249401510647666075672902952039936285914784670932211050696164514848,
#         "aTokenAddress": "0x4579a27aF00A62C0EB156349f31B345c08386419",
#         "stableDebtTokenAddress": "0xc9335dE638f4C96a8330b2FFc44353Bab58774e3",
#         "variableDebtTokenAddress": "0xeFFDE9BFA8EC77c14C364055a200746d6e12BeD6",
#         "ltv": 0.72,
#         "liquidationThreshold": 0.75,
#         "liquidationBonus": 1.085,
#         "decimals": 18,
#         "reserveIsActive": true,
#         "reserveIsFrozen": false,
#         "borrowingEnabled": false,
#         "stableRateBorrowingEnabled": false,
#         "assetIsPaused": false,
#         "borrowingInIsolationModeEnabled": false,
#         "siloedBorrowingEnabled": false,
#         "flashLoaningEnabled": true,
#         "reserveFactor": 0.2,
#         "borrowCap": 0,
#         "supplyCap": 4000000,
#         "liquidationProtocolFee": 0.1,
#         "eModeCategoryId": 0,
#         "unbackedMintCap": 0,
#         "debtCeilingForIsolationMode": 4000000000,
#         "virtualAccountingEnabled": true
#     },
#     {
#         "timestamp": 1727302495,
#         "symbol": "tBTC",
#         "price": 63057,
#         "assetAddress": "0x18084fbA666a33d37592fA2633fD49a74DD93a88",
#         "configuration": 7237005577332262213973186568751985011698905778191118104898618856892876201092,
#         "aTokenAddress": "0x10Ac93971cdb1F5c778144084242374473c350Da",
#         "stableDebtTokenAddress": "0xCcf8413F9cA3bAE07EEF05E265D238d60abCb8Ca",
#         "variableDebtTokenAddress": "0xAC50890a80A2731eb1eA2e9B4F29569CeB06D960",
#         "ltv": 0.73,
#         "liquidationThreshold": 0.78,
#         "liquidationBonus": 1.075,
#         "decimals": 18,
#         "reserveIsActive": true,
#         "reserveIsFrozen": false,
#         "borrowingEnabled": true,
#         "stableRateBorrowingEnabled": false,
#         "assetIsPaused": false,
#         "borrowingInIsolationModeEnabled": false,
#         "siloedBorrowingEnabled": false,
#         "flashLoaningEnabled": true,
#         "reserveFactor": 0.2,
#         "borrowCap": 275,
#         "supplyCap": 550,
#         "liquidationProtocolFee": 0.1,
#         "eModeCategoryId": 0,
#         "unbackedMintCap": 0,
#         "debtCeilingForIsolationMode": 0,
#         "virtualAccountingEnabled": true
#     },
#     {
#         "timestamp": 1727302495,
#         "symbol": "cbBTC",
#         "price": 63492.02767383335,
#         "assetAddress": "0xcbB7C0000aB88B473b1f5aFd9ef808440eed33Bf",
#         "configuration": 7237005577332262213973186568751985011727982640598635086679875456876559211652,
#         "aTokenAddress": "0x5c647cE0Ae10658ec44FA4E11A51c96e94efd1Dd",
#         "stableDebtTokenAddress": "0x0002BfcCE657a4BEB498E23201bd767FC5A0A0d5",
#         "variableDebtTokenAddress": "0xeB284A70557EFe3591b9e6D9D720040E02c54a4d",
#         "ltv": 0.73,
#         "liquidationThreshold": 0.78,
#         "liquidationBonus": 1.075,
#         "decimals": 8,
#         "reserveIsActive": true,
#         "reserveIsFrozen": false,
#         "borrowingEnabled": true,
#         "stableRateBorrowingEnabled": false,
#         "assetIsPaused": false,
#         "borrowingInIsolationModeEnabled": false,
#         "siloedBorrowingEnabled": false,
#         "flashLoaningEnabled": true,
#         "reserveFactor": 0.2,
#         "borrowCap": 45,
#         "supplyCap": 900,
#         "liquidationProtocolFee": 0.1,
#         "eModeCategoryId": 0,
#         "unbackedMintCap": 0,
#         "debtCeilingForIsolationMode": 0,
#         "virtualAccountingEnabled": true
#     }
# ]

# %%
df = pd.DataFrame(data)



### Save this dataframe to a csv
df.to_csv("aave_asset_data.csv", index=False)

# %%
ABI_BAL = [{"inputs":[{"internalType":"address[]","name":"addresses","type":"address[]"},{"internalType":"address","name":"tokenAddress","type":"address"}],"name":"checkBalances","outputs":[{"internalType":"uint256[]","name":"","type":"uint256[]"}],"stateMutability":"view","type":"function"}]
BAL_ADDRESS = "0x2a879c62119DcA3601e54990F712F1bBf026612c"
INFURA_URL = f"https://mainnet.infura.io/v3/{INFURA_KEY}"
W33 = Web3(HTTPProvider(INFURA_URL))

def get_user_balance(user_addrress_list, asset, block_number=None):
    
    try:
        # Create contract instance
        contract = W33.eth.contract(address=Web3.to_checksum_address(BAL_ADDRESS), abi=ABI_BAL)
        
        # Get the contract function
        contract_function = getattr(contract.functions, "checkBalances")
        
        # Call the function with arguments and block identifier if provided
        if block_number is not None:
            data = contract_function(user_addrress_list,asset).call(block_identifier=int(block_number))
        else:
            data = contract_function(user_addrress_list,asset).call()
        
        return data
    
    except Exception as e:
        return f'Error querying smart contract: {e}'

# %%
from dune_client.types import QueryParameter
from dune_client.client import DuneClient
from dune_client.query import QueryBase

# Explicitly specify the path to .env file using forward slashes
load_dotenv(dotenv_path='../.env')

dune = DuneClient(
    api_key=os.getenv('DUNE_API_KEY2'),
    base_url="https://api.dune.com",
    request_timeout=5000 # request will time out after 300 seconds
)

# %%
query = QueryBase(
    query_id=4101003,
    params=[],
)

users = dune.run_query_dataframe(query)
users["timestamp"] = unix_timestamp


### Save this dataframe to a csv
users.to_csv("users.csv", index=False)


# Create a list of user addresses
user_addresses = users['user'].tolist()

users_checksum = []
for user in user_addresses:
    users_checksum.append(Web3.to_checksum_address(user))
# Out:
# 2024-09-25 18:19:37,162 INFO dune_client.api.base executing 4101003 on medium cluster
# 2024-09-25 18:19:37,702 INFO dune_client.api.base waiting for query execution 01J8NM9EVH7H7BWWB0AA5M67XP to complete: ExecutionState.PENDING (queue position: 1)
# 2024-09-25 18:19:38,830 INFO dune_client.api.base waiting for query execution 01J8NM9EVH7H7BWWB0AA5M67XP to complete: ExecutionState.EXECUTING
# 2024-09-25 18:19:39,958 INFO dune_client.api.base waiting for query execution 01J8NM9EVH7H7BWWB0AA5M67XP to complete: ExecutionState.EXECUTING
# 2024-09-25 18:19:41,089 INFO dune_client.api.base waiting for query execution 01J8NM9EVH7H7BWWB0AA5M67XP to complete: ExecutionState.EXECUTING
# 2024-09-25 18:19:42,216 INFO dune_client.api.base waiting for query execution 01J8NM9EVH7H7BWWB0AA5M67XP to complete: ExecutionState.EXECUTING
# 2024-09-25 18:19:43,342 INFO dune_client.api.base waiting for query execution 01J8NM9EVH7H7BWWB0AA5M67XP to complete: ExecutionState.EXECUTING
# 2024-09-25 18:19:44,469 INFO dune_client.api.base waiting for query execution 01J8NM9EVH7H7BWWB0AA5M67XP to complete: ExecutionState.EXECUTING

# %%
# data_test = data[0:1]

user_position = []
for user in users_checksum:
    user_position_dict = {"user": user}
    user_position_dict["timestamp"] = unix_timestamp
    user_position.append(user_position_dict)

for asset in data:
    decimals = asset["decimals"]
    
    atoken_symbol = f"a{asset['symbol']}"
    dtoken_symbol = f"d{asset['symbol']}"
    
    atoken_balance = get_user_balance(users_checksum, asset["aTokenAddress"])
    dtoken_balance = get_user_balance(users_checksum, asset["variableDebtTokenAddress"])
    
    for index, user_dict in enumerate(user_position):
        user_dict[atoken_symbol] = atoken_balance[index] / 10**decimals
        user_dict[dtoken_symbol] = dtoken_balance[index] / 10**decimals
        
# Convert this to a dataframe
df_user_position = pd.DataFrame(user_position)

# Save this dataframe to a csv
df_user_position.to_csv("user_position.csv", index=False)

# %%
'''
  struct ReserveData {
    //stores the reserve configuration
    ReserveConfigurationMap configuration;
    //the liquidity index. Expressed in ray
    uint128 liquidityIndex;
    //the current supply rate. Expressed in ray
    uint128 currentLiquidityRate;
    //variable borrow index. Expressed in ray
    uint128 variableBorrowIndex;
    //the current variable borrow rate. Expressed in ray
    uint128 currentVariableBorrowRate;
    //the current stable borrow rate. Expressed in ray
    uint128 currentStableBorrowRate;
    //timestamp of last update
    uint40 lastUpdateTimestamp;
    //the id of the reserve. Represents the position in the list of the active reserves
    uint16 id;
    //timestamp until when liquidations are not allowed on the reserve, if set to past liquidations will be allowed
    uint40 liquidationGracePeriodUntil;
    //aToken address
    address aTokenAddress;
    //stableDebtToken address
    address stableDebtTokenAddress;
    //variableDebtToken address
    address variableDebtTokenAddress;
    //address of the interest rate strategy
    address interestRateStrategyAddress;
    //the current treasury balance, scaled
    uint128 accruedToTreasury;
    //the outstanding unbacked aTokens minted through the bridging feature
    uint128 unbacked;
    //the outstanding debt borrowed against this asset in isolation mode
    uint128 isolationModeTotalDebt;
    //the amount of underlying accounted for by the protocol
    uint128 virtualUnderlyingBalance;
  }
  
((7237005577332262213973186942896404317902510153474528182451012586290352496498,),
 1031659215120487790563166607,
 19627221359796060493882528,
 1052348817879507493709217434,
 26319678184915331852416053,
 0,
 1727291135,
 0,
 '0x4d5F47FA6A74757f35C14fD3a6Ef8E3C9BC514E8',
 '0x102633152313C81cD80419b6EcF66d14Ad68949A',
 '0xeA51d7853EEFb32b6ee06b1C12E6dcCA88Be0fFE',
 '0x847A3364Cc5fE389283bD821cfC8A477288D9e82',
 37387375566166645479,
 0,
 0)
  
  struct ReserveConfigurationMap {
    //bit 0-15: LTV
    //bit 16-31: Liq. threshold
    //bit 32-47: Liq. bonus
    //bit 48-55: Decimals
    //bit 56: reserve is active
    //bit 57: reserve is frozen
    //bit 58: borrowing is enabled
    //bit 59: stable rate borrowing enabled
    //bit 60: asset is paused
    //bit 61: borrowing in isolation mode is enabled
    //bit 62: siloed borrowing enabled
    //bit 63: flashloaning enabled
    //bit 64-79: reserve factor
    //bit 80-115: borrow cap in whole tokens, borrowCap == 0 => no cap
    //bit 116-151: supply cap in whole tokens, supplyCap == 0 => no cap
    //bit 152-167: liquidation protocol fee
    //bit 168-175: eMode category
    //bit 176-211: unbacked mint cap in whole tokens, unbackedMintCap == 0 => minting disabled
    //bit 212-251: debt ceiling for isolation mode with (ReserveConfiguration::DEBT_CEILING_DECIMALS) decimals
    //bit 252: virtual accounting is enabled for the reserve
    //bit 253-255 unused
'''
